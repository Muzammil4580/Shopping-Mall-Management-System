# %%
import pandas
import csv
print("\n\nWelcome to Shopping Mall Management System")

def displayMain():
    print("For Employes Details Press 1")
    print("For Sales Details Press 2")
    print("For Customer Details Press 3")
    print("For Supplier Details Press 4")
    print("For Order Details Press 5")
    print("For Exit Press 6")
    a = int(input("Enter the number in menu you want To proceed"))
    if a==1:
        print("\n\nWelcome to Employe Details Menu")
        employe()
    elif a==2:
        print("\n\nWelcome to Sales Details Menu")
        sales()
    elif a==3:
        print("\n\nWelcome to Customer Details Menu")
        cust()
    elif a==4:
        print("\n\nWelcome to Supplier Details Menu")
        sup()
    elif a==5:
        print("\n\nWelcome to Order Details Menu")
        order()
    else:
        quit()
    return
####
################

def employe():
    while 1:
        print("\n\n1.Insert\n2.Show\n3.Update\n4.Delete\n5.Main Menu\n")
        b = int(input("Enter the number from Menu to Proceed"))
        if b==1:
            from csv import writer
            am = str(input("Enter ID No: "))
            bm = str(input("Enter Employe Name"))
            cm = str(input("Enter Employe Status"))
            dm = int(input("Enter Salary"))
            list_data = [am, bm, cm, dm]
            with open('Employe.csv', 'a', newline='') as f_object:
                writer_object= writer(f_object)
                writer_object.writerow(list_data)
                f_object.close()
        elif b==2:
            milk=pandas.read_csv('Employe.csv')
            print(milk)
        elif b==3:
            n = int(input("Enter the number of row in which replacement is made: "))
            N = str(input("Enter the name of column in which you want replacement"))
            r = str(input("Enter the new thing"))
            v = n-1
            df = pandas.read_csv('Employe.csv')
            df.loc [v, N] = r
            df.to_csv('Liab.csv', index = False)
            print(df)
        elif b==4:
            n = int(input("Enter the ID of Employe Whose Data you want to delete:"))
            v = pandas.read_csv('Employe.CSV')
            d = v[: 4]
            d.set_index('Employe ID', inplace=True)
            d = d.drop(n)
            print(d)
        elif b==5:
            displayMain()
##############################################


#===================================================

def sales():
    while 1:
        print("\n\n1.Insert\n2.Show\n3.Main Menu\n")
        c = int(input("Enter the number from Menu to Proceed"))
        if c==1:
            from csv import writer
            am = str(input("Enter Date"))
            bm = str(input("Enter Item Name"))
            cm = int(input("Enter Item Quantity"))
            dm = int(input("Enter Total Bill"))
            list_data = [am, bm, cm, dm]
            with open('Sales.csv', 'a', newline='') as f_object:
                writer_object= writer(f_object)
                writer_object.writerow(list_data)
                f_object.close()
        elif c==2:
            milk=pandas.read_csv('Sales.csv')
            print(milk)
        elif c==3:
            displayMain()
##############################################


#===================================================

def cust():
    while 1:
        print("\n\n1.Insert\n2.Show\n3.Main Menu\n")
        b = int(input("Enter the number from Menu to Proceed"))
        if d==1:
            from csv import writer
            am = str(input("Enter ID"))
            bm = str(input("Enter Customer Name"))
            cm = int(input("Enter Customer Type"))
            dm = int(input("Enter Mobile Number"))
            list_data = [am, bm, cm, dm]
            with open('Cust.csv', 'a', newline='') as f_object:
                writer_object= writer(f_object)
                writer_object.writerow(list_data)
                f_object.close()
        elif d==2:
            milk=pandas.read_csv('Cust.csv')
            print(milk)
        else:
            displayMain()
##############################################


#===================================================

def sup():
    while 1:
        print("\n\n1.Insert\n2.Show\n3.Update\n4.Delete\n5.Main Menu\n")
        e = int(input("Enter the number from Menu to Proceed"))
        if e==1:
            from csv import writer
            am = str(input("Enter Suppliers Name"))
            bm = str(input("Enter Suppliers Adress"))
            cm = str(input("Enter Suppliers Shift"))
            list_data = [am, bm, cm]
            with open('sup.csv', 'a', newline='') as f_object:
                writer_object= writer(f_object)
                writer_object.writerow(list_data)
                f_object.close()
        elif e==2:
            milk=pandas.read_csv('sup.csv')
            print(milk)
        elif e==3:
            n = int(input("Enter the number of row in which replacement is made: "))
            N = str(input("Enter the name of column in which you want replacement"))
            r = str(input("Enter the new thing"))
            v = n
            df = pandas.read_csv('sup.csv')
            df.loc [v, N] = r
            df.to_csv('sup.csv', index = False)
            print(df)
        elif e==4:
            n = str(input("Enter the Name of Supplier you want to delete:"))
            v = pandas.read_csv('sup.CSV')
            d = v[: 3]
            d.set_index('Shop Name', inplace=True)
            d = d.drop(n)
            print(d)
        elif e==5:
            displayMain()
##############################################


#===================================================

def order():
    while 1:
        print("\n\n1.Insert\n2.Show\n3.Main Menu\n")
        f = int(input("Enter the number from Menu to Proceed"))
        if f==1:
            from csv import writer
            dm = int(input("Enter Order ID"))
            am = str(input("Enter Date"))
            bm = str(input("Enter Item Name"))
            cm = int(input("Enter Item Quantity"))
            em = str(input("Enter Time"))
            list_data = [dm, am, bm, cm, em]
            with open('order.csv', 'a', newline='') as f_object:
                writer_object= writer(f_object)
                writer_object.writerow(list_data)
                f_object.close()
        elif f==2:
            milk=pandas.read_csv('order.csv')
            print(milk)
        else:
            displayMain()
##############################################


#===================================================
displayMain()
# Out:
# Welcome to Shopping Mall Management System
# For Employes Details Press 1
# For Sales Details Press 2
# For Customer Details Press 3
# For Supplier Details Press 4
# For Order Details Press 5
# For Exit Press 6
# Enter the number in menu you want To proceed2
#
#
# Welcome to Sales Details Menu
#
#
# 1.Insert
# 2.Show
# 3.Main Menu
